# %% [markdown]
# Goodreads doesnt give public APIs anymore, but here's 2 things I found -
#
# 1. https://rapidapi.com/puresoft-labs-ou-puresoft-labs-ou-default/api/goodreads-api-latest-updated
#
# Gives info about books, but has 35 req a month limit, no use.
#
# 2. https://www.piratereads.com/
#
# Fetching a user's books info from different shelves.

# %%
import requests

# %% [markdown]
# Goodreads user ids -
#
# Suryam - 142334643
#
# Priyanshi - 146586308

# %%
suryam_id = 142334643
pri_id = 146586308

# %%
response = requests.get(f"https://api.piratereads.com/{suryam_id}/read")
data = response.json()
print(data)

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['count', 'books'])

# %%
data['count']
# Out:
# 77

# %%
type(data['books'])
# Out:
# list

# %%
len(data['books'])
# Out:
# 77

# %%
data['books'][0]
# Out:
# {'book_title': 'The Metamorphosis',
#  'book_author': 'Franz Kafka',
#  'book_cover_small': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1646444605l/485894._SY75_.jpg',
#  'book_cover_medium': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1646444605l/485894._SY160_.jpg',
#  'book_cover_large': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1646444605l/485894._SY475_.jpg',
#  'book_link': 'https://www.goodreads.com/book/show/485894.The_Metamorphosis?utm_medium=api&amp;utm_source=rss',
#  'avg_rating': 3.91,
#  'rating': 4,
#  'review_text': 'Great read, the story had an almost perfect flow!<br /><br />A few of my friends seem to be unsure about their interpretation of the story and if they understand the metaphor correctly, so now when i feel like i completely understand it, it kinda makes me unsure too lol. But i am pretty sure the story is just about what i read in an insta post (which also made me first understand that it\'s not just about a person who has suddenly turned into a vermin), which is:<br />Kafka spoke to all humanity when he said, "When Gregor Samsa discovered that he had turned into an insect, his first concern was not to be late for work.."<br /><br />Soooo i think that\'s pretty much it, bro\'s entire personality was providing for his family and making sure they and his bosses were always happy, he felt that he couldn\'t ever disappoint anyone about anything and went to extremes like not missing a day at work for many many years straight, basically the guy wasn\'t living for himself anymore. The family, who got used to being provided and fed by him (i am actually not sure about this because it felt like at the least the mother and sister did truly love him, what with the "let\'s not remove all furniture so he doesn\'t think we want to forget him" by his mom and the sister being soooo considerate and helpful with his situation initially), just couldn\'t take it anymore when he couldn\'t do so anymore, and was sooo easily forgotten (this parts makes you so sad) and kinda left to die. I felt so so bad at the end where Gregor was all love and affectionate about his sister and the very next moment Greta just turned against him and "wanted to get rid of it" (she used the word "it"',
#  'review_published_on': 'Sun, 25 Jan 2026 10:30:10 -0800'}

# %%
for i in range(5):
    print(data['books'][i]['review_published_on'])
# Out:
# Sun, 25 Jan 2026 10:30:10 -0800
# Mon, 12 Jan 2026 15:11:38 -0800
# Mon, 29 Dec 2025 19:48:23 -0800
# Mon, 29 Dec 2025 14:31:26 -0800
# Mon, 29 Dec 2025 14:17:01 -0800

# %%
data1 = requests.get(f"https://api.piratereads.com/{pri_id}/read").json()

# %%
data1['books'][0]
# Out:
# {'book_title': 'Deewar Mein Ek Khirkee Rahati Thee (3rd) (Hindi Edition)',
#  'book_author': 'Vinod Kumar Shukla',
#  'book_cover_small': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1523427929l/39800154._SX50_.jpg',
#  'book_cover_medium': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1523427929l/39800154._SX98_.jpg',
#  'book_cover_large': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1523427929l/39800154._SX318_.jpg',
#  'book_link': 'https://www.goodreads.com/book/show/39800154-deewar-mein-ek-khirkee-rahati-thee-3rd?utm_medium=api&amp;utm_source=rss',
#  'avg_rating': 4.25,
#  'rating': 4,
#  'review_text': 'Starting 2026 strong with the book bought compulsively from railway platform since my train got delayed and that i finished on an airport because my flight got delayed. <br /><br />I can\'t say I am an expert in the kind of writing here but here are my two cents<br /><br />I have been a Vinod Kumar Shukla fan since I read his poem "हताशा से एक व्यक्ति बैठ गया था" (highly recommend it btw). This book is the winner of Sahitya Akademi Prize 1999, an achievement in itself. I had settled for it, having met with disappointment at the unavailability of my first choice. and I am quite happy to have a new experience in writing.<br /><br />In terms of my knowledge of Hindi literature, I have somehow seen similarities in this book and Munshi Premchand\'s works. The major theme of rural Indian people living out their normal routine while things unfold around them is same in both the works. However, while Premchand focusses more on the hardships and attrocities they go through, this book painted a picture of a hopeful society where people help each other, understand each other and become a company for each other. It is a very simple story of a rural couple living their newly married life with hints of magic. N0thing spectacular or out of the blue happens. The books feels like a very calming experience. <br /><br />I am happy to have been handed it and I would highly recommend it to anyone looking for a light read.',
#  'review_published_on': 'Mon, 02 Feb 2026 06:41:56 -0800'}

# %%
want_to_read = requests.get(f"https://api.piratereads.com/{pri_id}/want-to-read").json()

# %%
want_to_read.keys()
# Out:
# dict_keys(['count', 'books'])

# %%
want_to_read['count']
# Out:
# 53

# %%
want_to_read['books'][0]
# Out:
# {'book_title': 'What We Talk About When We Talk About Love',
#  'book_author': 'Raymond Carver',
#  'book_cover_small': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1475474209l/11438._SY75_.jpg',
#  'book_cover_medium': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1475474209l/11438._SX98_.jpg',
#  'book_cover_large': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1475474209l/11438.jpg',
#  'book_link': 'https://www.goodreads.com/book/show/11438.What_We_Talk_About_When_We_Talk_About_Love?utm_medium=api&amp;utm_source=rss',
#  'avg_rating': 4.09}

# %%
currently_reading = requests.get(f"https://api.piratereads.com/{pri_id}/currently-reading").json()
currently_reading.keys()
# Out:
# dict_keys(['count', 'books'])

# %%
currently_reading['count']
# Out:
# 2

# %%
currently_reading['books'][0]
# Out:
# {'book_title': 'Gaban',
#  'book_author': 'Munshi Premchand',
#  'book_cover_small': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1338110152l/11692391._SY75_.jpg',
#  'book_cover_medium': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1338110152l/11692391._SX98_.jpg',
#  'book_cover_large': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1338110152l/11692391.jpg',
#  'book_link': 'https://www.goodreads.com/book/show/11692391-gaban?utm_medium=api&amp;utm_source=rss',
#  'avg_rating': 4.31}

# %%
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model="llama-3.3-70b-versatile")

# %%
llm.invoke("What is the capital of France?")
# Out:
# AIMessage(content='The capital of France is Paris.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 42, 'total_tokens': 50, 'completion_time': 0.015905988, 'completion_tokens_details': None, 'prompt_time': 0.001914534, 'prompt_tokens_details': None, 'queue_time': 0.150647903, 'total_time': 0.017820522}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_ce7bc1685b', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d09ae-60dc-7c12-a868-1f19f563f585-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 8, 'total_tokens': 50})

# %%
llm.invoke("Give a brief summmary of {}".format(data['books'][0]['book_title']))
# Out:
# AIMessage(content='"The Metamorphosis" is a novella by Franz Kafka, published in 1915. The story revolves around Gregor Samsa, a traveling salesman who wakes up one morning to find himself transformed into a giant insect-like creature. This physical transformation leads to a series of emotional, psychological, and social changes that affect not only Gregor but also his family.\n\nAs Gregor struggles to cope with his new form, he becomes isolated and confined to his room, relying on his family for care and support. However, his transformation also leads to a reversal of roles, with Gregor\'s family members taking on new responsibilities and attitudes towards him.\n\nThroughout the novella, Kafka explores themes of identity, alienation, and the human condition, raising questions about the nature of self and the consequences of change. The story is a powerful and thought-provoking exploration of the complexities of human relationships and the search for meaning in a seemingly meaningless world.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 192, 'prompt_tokens': 46, 'total_tokens': 238, 'completion_time': 0.446401874, 'completion_tokens_details': None, 'prompt_time': 0.005423036, 'prompt_tokens_details': None, 'queue_time': 0.234133313, 'total_time': 0.45182491}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_45180df409', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d0c50-3fad-77f2-82a8-d3a400ad0167-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 46, 'output_tokens': 192, 'total_tokens': 238})
